# %%
import pandas as pd

# %% [markdown]
# ### Import csv

# %%
csv_data = pd.read_csv('artwork_data.csv')
print(dcsv_ata.shape)
csv_data.head(5)
# Out:
# (69201, 20)
# C:\Users\Mary's PC\AppData\Local\Temp\ipykernel_24180\1722612233.py:1: DtypeWarning: Columns (9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('artwork_data.csv')
#      id accession_number          artist artistRole  artistId
# 0  1035           A00001   Blake, Robert     artist        38  \
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText
# 0  A Figure Bowing before a Seated Old Man with h...          date not known  \
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# ...

# %% [markdown]
# ### Import Text files

# %%
text_data = pd.read_csv("test.txt", sep="/t", index_col=0)
text_data

# %%
text_data = pd.read_table("test.txt")
text_data

# %% [markdown]
# ### Import Excel

# %%
excel_data = pd.ExcelFile("basic.xlsx")
excel_data.sheet_names
# Out:
# ['Sheet1']

# %%
specific_sheet = excel_data.parse('Sheet1')
specific_sheet.head(5)
# Out:
#   artist       title  year
# 0   Wols  [no title]  1937
# 1   Wols  [no title]  1937
# 2   Wols  [no title]  1937
# 3   Wols  [no title]  1937
# 4   Wols  [no title]  1937

# %% [markdown]
# ### Import from URL

# %%
url = 'https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv'
url_data = pd.read_csv(url)
url_data
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ### Import SQL Databases

# %%
import pyodbc 
sql_conn = pyodbc.connect("Driver={SQL Server};Server=serverName;UID=UserName;PWD=Password;Database=sql_db;")
df_sql = pd.read_sql_query('type your sql query here', sql_conn)
df_sql.head()
